# %% [markdown]
# Data Visualiazation With Seaborn

# %% [markdown]
# Seaborn is a popular Python library for creating attractive statistical visualizations. Built on Matplotlib and integrated with Pandas, it simplifies complex plots like line charts, heatmaps and violin plots with minimal code.

# %% [markdown]
# Creating Plots with Seaborn
# Seaborn makes it easy to create clear and informative statistical plots with just a few lines of code. It offers built-in themes, color palettes, and functions tailored for different types of data.
#
# Let’s see various types of plots with simple code to understand how to use it effectively.
#
# 1. Line plot
# A line plot shows the relationship between two numeric variables, often over time. It can also compare multiple groups using different lines.
#
# Syntax:
#
# sns.lineplot(x=None, y=None, data=None)

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
## Basic Plotting With Seaborn

tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## Create a Scatter plot
import matplotlib.pyplot as plt      

sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.title("Scatter Plot of Total Bill vs Tip")
plt.show()

# %%
## Line Plot

sns.lineplot(x='size',y='total_bill',data=tips)
plt.title("Line Plot of Total bill by size ")
# Out:
# Text(0.5, 1.0, 'Line Plot of Total bill by size ')

# %%
## Ccategorical plots
## Bar Plot

sns.barplot(x='day',y='total_bill',data=tips)
plt.title('Bar Plot of Total Bill By Day')
plt.show()

# %%
## Box Plot 

sns.boxplot(x='day',y='total_bill',data=tips)
plt.title("Box Plot of Day By totalbill")
plt.show()

# %%
## Violin Plot

sns.violinplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
## Histograms

sns.histplot(tips['total_bill'],bins=10,kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
## KDE Plot

sns.kdeplot(tips['total_bill'],shade=True)
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_3720\1706642080.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips['total_bill'],shade=True)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
## pairplot

sns.pairplot(tips)

# %%
## heatmap

corr=tips[['total_bill','tip','size']].corr() ## corelation
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
import pandas as pd

sales_df=pd.read_csv('friends.csv')
sales_df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
# plot total sales by product

plt.Figure(figsize=(10,9))
sns.barplot(x='Item Type',y='Total Revenue',data=sales_df,estimator=sum)
# Out:
# <Axes: xlabel='Item Type', ylabel='Total Revenue'>

# %%
## Plot total sales by product 
plt.Figure(figsize=(10,6))
sns.barplot(x='Country',y='Total Revenue',data=sales_df,estimator=sum)
# Out:
# <Axes: xlabel='Country', ylabel='Total Revenue'>
