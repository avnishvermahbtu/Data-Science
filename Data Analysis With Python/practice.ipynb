# %%
import matplotlib.pyplot as plt    

x=[1,2,3,4,5]
y=[2,3,5,6,2]
y1=[1,2,3,4,5]

plt.figure(figsize=(9,5))

plt.subplot(2,2,2)
plt.plot(x,y,marker='.',linestyle='--',linewidth=1)
plt.title('Plot 1')

plt.subplot(2,2,2)
plt.plot(y,x,marker='.')
plt.title('plot 2')
# Out:
# Text(0.5, 1.0, 'plot 2')
